# %%
try:
    print('step1')
    a=5/0
    print('step2')
except ZeroDivisionError as e:
    print('step3')
    print(e)
print('step4')
# Out:
# step1
# step3
# division by zero
# step4

# %%
while True:
    try:
        a=int(input('请输入一个整数：'))
        print('输入的整数是：',a)
        break
    except ValueError as e:
        print('输入错误，请重新输入！')
# Out:
# 输入的整数是： 66

# %%
#try 多个·except
try:
  a = input("请输入被除数：")
  b = input("请输入除数：")
  c = float(a)/float(b)
  print(c)
except ZeroDivisionError:
  print("异常：除数不能为0")
except TypeError:
  print("异常：除数和被除数都应该为数值类型")
except BaseException as e:
  print(e)
  print(type(e))
# Out:
# could not convert string to float: ''
# <class 'ValueError'>

# %%
#try...except...else
try:
  a = input("请输入被除数：")
  b = input("请输入除数：")
  c = float(a)/float(b)
except BaseException as e:
  print(e)
else:
  print("除的结果是：",c)
# Out:
# 除的结果是： 1.0

# %%
#finally结构和return语句
try:
  a = input("请输入一个被除数：")
  b = input("请输入一个除数：")
  c = float(a)/float(b)
except BaseException as e:
  print(e)
else:
  print(c)
finally:
  print("我是finally中的语句，无论发生异常与否，都执行！")
print("程序结束！")
# Out:
# float division by zero
# 我是finally中的语句，无论发生异常与否，都执行！
# 程序结束！

# %%
try:
    a = input("请输入一个被除数：")
    b = input("请输入一个除数：")
    c = float(a)/float(b)
except BaseException as e :
     print(e)
else:
     print(c)
finally:
     print("我是finally中的语句，无论发生异常与否，都执行！")
# Out:
# float division by zero
# 我是finally中的语句，无论发生异常与否，都执行！

# %%
#traceback模块
import traceback
try:
    a = input("请输入一个被除数：")
    b = input("请输入一个除数：")
    c = float(a)/float(b)
except BaseException as e :
     print(e)
     #traceback.print_exc()  #打印异常的详细信息
     print(traceback.format_exc())
else:     print(c)
finally:     print("我是finally中的语句，无论发生异常与否，都执行！")
# Out:
# float division by zero
# Traceback (most recent call last):
#   File "C:\Users\libing\AppData\Local\Temp\ipykernel_57756\475943620.py", line 6, in <module>
#     c = float(a)/float(b)
#         ~~~~~~~~^~~~~~~~~
# ZeroDivisionError: float division by zero
#
# 我是finally中的语句，无论发生异常与否，都执行！
