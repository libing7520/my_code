# %%
from matplotlib import pyplot as plt
import seaborn as sns
tip=sns.load_dataset('tips')
sns.scatterplot(x='total_bill',y='tip',data=tip)
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=tip,col='sex')
plt.show()
